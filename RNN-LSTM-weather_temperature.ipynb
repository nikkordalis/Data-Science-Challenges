# %% [markdown]
# # 🌤 Weather Temperature

# %% [markdown]
# ### Libraries

# %% [markdown]
# * Let's import the usual libraries:

# %%
# Data manipulation
import numpy as np
import pandas as pd
pd.set_option("max_columns", None)

# Data Visualiation
import matplotlib.pyplot as plt
import seaborn as sns

# System
import os

# Deep Learning
import tensorflow as tf
# Out:
# /home/nikkord/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2024-01-15 21:30:51.590047: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-01-15 21:30:51.590113: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# * Manipulating temporal data is tricky, let's also import 📚 [`typing`](https://docs.python.org/3/library/typing.html) to check the types of variables we will be dealing with in our Python functions:

# %%
from typing import Dict, List, Tuple, Sequence

# %% [markdown]
# # (0) The weather temperature challenge

# %% [markdown]
# ## (0.0) Introduction

# %% [markdown]
# 🧑🏻‍🏫 **Goals:**
# - Prepare a dataset to be fed into a Recurrent Neural Network
# - Develop a better understanding of Time Series
#
# ❗️ **Warning/Disclaimer**:
# - This challenge is truly designed to help you understand **how to deal with temporal data**, using an LSTM architecture as a _tool_, not to focus on the different gates of the LSTM or designing the "best" recurrent network.

# %% [markdown]
# 🎯 **ML target**:
# * In this challenge, we want to **predict the temperature in the next 3, 6, 9, 12... hours**...
# * ...based on a sequence of weather features such as the _past temperature_, the _atmospheric pressure_, the _humidity_, etc..

# %% [markdown]
# ## (0.1) The weather dataset

# %% [markdown]
# ### (0.1.1) Loading the dataset

# %% [markdown]
# 🌤 This challenge uses a [**weather time series dataset**](https://www.bgc-jena.mpg.de/wetter/) recorded by the [**Max-Planck-Institute for Biogeochemistry**](https://www.bgc-jena.mpg.de/index.php/Main/HomePage). This dataset contains $14$ different features such as _air temperature_, _atmospheric pressure_ and _humidity_ that were collected starting in 2003 every 10 minutes (~ 420k rows). But for efficiency, you will use "only" the data collected between 2009 and 2016 every three hours. Indeed, this time interval seems reasonable to observe the evolution of the temperature throughout a given day.
#
# 🛠 We've already performed the following feature engineering steps for you:
# - taking every $18$th record to focus on predictions every three hours $ ( 18 =  \frac{6 records}{hour} \times 3 hours)$
# - replacing absurd values
# - _wind_: computing the wind directions as wind vectors with coordinates (`Wx`, `Wy`)
# - computing _the daily and yearly periodicities_, stored through (`Day sin`, `Day cos`) and (`Year sin`, `Year cos`)

# %% [markdown]
# ##### (Keep this section for later) Downloading the original dataset and engineer the features manually
#
# _(Toggle the section to hide it for the moment)_

# %% [markdown]
# 🥋 If you want to practice your feature engineering skills, feel free to download the original dataset and work on it (but not today, there are many questions and reading sections to cover 😉)

# %%
#########################################################
# Uncomment later -not today- to download the original  #
# dataset and try to perform the features engineering   #
# by yourself                                           #
#########################################################


zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True)
csv_path, _ = os.path.splitext(zip_path)

raw = pd.read_csv(csv_path)

print(f"raw.shape = {raw.shape}")
display(raw.head())

# %%
# Inspecting each feature to detect their type and null values
raw.info()

# %%
# Slice [start:stop:step], 
# starting from index 5, take every 6th record
# to get only hourly records

pass  # YOUR CODE HERE

# %%
# Convert the "Date Time" column to a datetime format

pass  # YOUR CODE HERE

# %%
# Describe the dataset

pass  # YOUR CODE HERE

# %%
## Fixing the wv

pass  # YOUR CODE HERE

## Fixing the max wv

pass  # YOUR CODE HERE

# %%
# Wind : Wd degrees from 0 to 360 egrees
# Angles do not make good models inputs because 0 and 360 should be "close"

print('-'*50)
print("Working with angles...")

plt.hist2d(df['wd (deg)'], df['wv (m/s)'], 
           bins=(50, 50), 
           vmax=400)
plt.colorbar()
plt.xlabel('Wind Direction [deg]')
plt.ylabel('Wind Velocity [m/s]')
plt.show()

# It is much easier for the model to interpret
# the wind direction and the wind velocity through a vector


# Convert degrees to radians and store the values into wd_rad
pass  # YOUR CODE HERE

# Calculate the wind x and y components and store then in two new columns
# `Wx` and `Wy`
pass  # YOUR CODE HERE

# Calculate the max wind x and y components and store then in two new columns
# `max Wx` and `max Wy`
pass  # YOUR CODE HERE

print('-'*50)
print("Working with wind vectors")

plt.hist2d(df['Wx'], df['Wy'], 
           bins=(50, 50), vmax=400)
plt.colorbar()
plt.xlabel('Wind X [m/s]')
plt.ylabel('Wind Y [m/s]')
ax = plt.gca()
ax.axis('tight')
plt.show()

# $CHALLENGIFY_END

# %%
# Similarly to the wind direction, the time in seconds is not a useful model input
# The weather dataset has clear daily and yearly periodicities
# Using sine and cosine functions, we can compute:
# - the time of the day
# - the time of the year

pass  # YOUR CODE HERE

# %%
# Select every 3 hours 

pass  # YOUR CODE HERE

# %% [markdown]
# ##### Trust us and start from this already preprocessed dataset for this challenge

# %%
url = "https://wagon-public-datasets.s3.amazonaws.com/deep_learning_datasets/weather_every_three_hours_engineered.csv"
df = pd.read_csv(url).drop(columns = ['Unnamed: 0'])
df
# Out:
#        p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 0        996.84     -8.81    264.59        -9.66   93.50          3.13
# 1        997.71     -9.67    263.66       -10.62   92.70          2.93
# 2        999.69     -7.66    265.52        -8.84   91.20          3.43
# 3       1000.30     -6.87    266.27        -8.28   89.60          3.64
# 4        999.88     -5.69    267.48        -7.00   90.40          3.99
# ...         ...       ...       ...          ...     ...           ...
# 23358   1006.23     -6.31    266.37        -8.42   84.90          3.81
# 23359   1004.62     -0.71    272.09        -5.97   67.37          5.80
# 23360   1003.09      4.97    277.88        -3.04   56.03          8.71
# 23361   1002.27     -0.42    272.56        -4.92   71.50          5.92
# 23362   1001.19     -2.75    270.32        -6.90   72.90          4.99
#
#        VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0              2.93          0.20       1.83             2.94       1312.18
# 1              2.71          0.21       1.69             2.72       1317.71
# 2              3.13          0.30       1.95             3.13       1310.14
# 3              3.27          0.38       2.03             3.26       1306.98
# 4              3.61          0.38       2.25             3.61       1300.51
# ...             ...           ...        ...              ...           ...
# 23358          3.23          0.57       2.00             3.21       1312.01
# 23359          3.91          1.89       2.42             3.89       1282.65
# 23360          4.88          3.83       3.03             4.86       1254.09
# 23361          4.23          1.69       2.63             4.22       1278.14
# 23362          3.64          1.35       2.26             3.63       1288.02
#
#              Wx        Wy    max Wx    max Wy       Day_sin       Day_cos  \
# 0     -0.175527  0.039879 -0.614344  0.139576  7.071068e-01  7.071068e-01
# 1     -0.041452  0.027960 -0.414519  0.279596  1.000000e+00  4.339955e-12
# 2     -0.314796 -0.128466 -0.583298 -0.238040  7.071068e-01 -7.071068e-01
# 3     -1.834577 -0.141163 -2.622249 -0.201771  6.903299e-12 -1.000000e+00
# 4     -0.825870  0.828758 -1.327039  1.331679 -7.071068e-01 -7.071068e-01
# ...         ...       ...       ...       ...           ...           ...
# 23358 -1.279930 -0.013404 -1.839899 -0.019268  6.755902e-01 -7.372773e-01
# 23359 -0.976457 -0.412471 -1.916066 -0.809378 -4.361939e-02 -9.990482e-01
# 23360 -0.403185 -0.359224 -0.776504 -0.691840 -7.372773e-01 -6.755902e-01
# 23361 -0.266024 -0.350473 -0.604599 -0.796530 -9.990482e-01  4.361939e-02
# 23362 -0.661501  0.257908 -1.453438  0.566672 -6.755902e-01  7.372773e-01
#
#        Year_sin  Year_cos
# 0      0.011483  0.999934
# 1      0.013633  0.999907
# 2      0.015783  0.999875
# 3      0.017933  0.999839
# 4      0.020083  0.999798
# ...         ...       ...
# 23358 -0.000268  1.000000
# 23359  0.001883  0.999998
# 23360  0.004033  0.999992
# 23361  0.006183  0.999981
# 23362  0.008334  0.999965
#
# [23363 rows x 19 columns]

# %% [markdown]
# 👆 In the preprocessed dataset, we have :
# - $23$k rows  (~ 8 years of weather data)
# - $19$ features composed of:
#     - $1$ <font color=green>**target**</font> (we will use the past values of the temperature as a feature)
#     - $18$ <font color=orange>**past covariates**</font> (= features which past values are known)
#     - $0$ <font color=blue>**future covariates**</font> (= features which future values are known, e.g. public holidays)
#
#
# <img src='https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/time-series-covariates.png'>
#
# 👨🏻‍🏫 This weather dataset is a DataFrame (dimension = 2) which is a single Time Series from the beginning of 2009 to the end 2016 with records every 3 hours.
#
# * `df.shape = (n_timesteps, n_features) = (23363, 19)`
#
# 🎯 The goal is to predict the temperature in 3, 6, 9, 12, ... hours using the past values.

# %% [markdown]
# ???X.shape = (n_SEQUENCES =?, n_OBSERVATIONS = 23363, n_FEATURES =19)

# %%
# Let's define the global variables of our dataset
TARGET = 'T (degC)'
N_TARGETS = 1
N_FEATURES = 19

# %% [markdown]
# ### (0.0.2) Visualising your Time Series

# %% [markdown]
# 📈  Here is the ***evolution of some features over time***:
# * `T (degC)` (temperature)
# * `p (mbar)` (atmospheric pressure)
# * `rho (g/m**3)` (atmospheric density)

# %%
plot_cols = [TARGET, 'p (mbar)', 'rho (g/m**3)']
plot_features = df[plot_cols]
plot_features.index = df.index
plot_features.plot(subplots = True);

# %%
zoomed_slice = slice(1000,1100)

plot_features = df.loc[zoomed_slice, plot_cols]
plot_features.plot(subplots = True);

# %% [markdown]
# # (1) Prepare the dataset

# %% [markdown]
# ##  (1.0) The big picture

# %% [markdown]
# <b><u>Step 1: Cross-Validation in Time Series [FOLDS] </u></b>
#
# * Starting from this single Time Series, we will create <font color="#c91ac9">**FOLDS**</font>...
# * ... and train/evaluate our LSTM on these different <font color="#c91ac9">**FOLDS**</font> to conclude about the robustness of the neural network
# * It is very common to create ***hundreds*** of <font color="#c91ac9">**FOLDS**</font> in Time Series forecasting, in order to to cover all types of external conditions: e.g.
#     - crash market periods 📉
#     - bull markets 📈
#     - atone markets 😴, etc...
#
# <b><u>Step 2: Holdout method within each fold [TRAIN-TEST SPLIT]</u></b>
#
# * For each <font color="#c91ac9">**FOLD**</font>, we will do a TRAIN-TEST SPLIT to:
#     * <font color=blue>**fit**</font> the model on the <font color=blue>**train**</font> set
#     * and <font color="#ff8005">**evaluate**</font> it on the <font color="#ff8005">**test**</font> set
#     * Always split the train set **chronologically** before the test set!
#
# 👇 The first two steps can be summarized in the following image that contains 4 FOLDS:
#
# <img src="https://bit.ly/3yLoa92" alt="Time Series Cross Validation" width="500" height="500">
#
#
# <b><u>Step 3: Sampling SEQUENCES in both the train set and the test set</u></b>
#
# In each <font color=blue>**train**</font> set and each <font color="#ff8005">**test**</font> set, we will create <font color=magenta>**random sequences**</font> as illustrated down below 👇:
#
# <img src="https://bit.ly/3Ri8Vfd" alt="Sequences in each fold" width="500" height="500">

# %% [markdown]
# ## (1.1) Creating  <font color="#c91ac9">**FOLDS**</font> for cross-validation
#
# Each of them with shape `(FOLD_LENGTH, n_features)`

# %% [markdown]
# 🌐 Let's define some global variables that we will use for our tests everywhere in this notebook:

# %%
# --------------------------------------------------- #
# Let's consider FOLDS with a length of 3 years       #
# (2 years will be used for train, 1 for test!)       #
# --------------------------------------------------- #

FOLD_LENGTH = 8*365 * 3 # every 3 hrs x 8 = 24h
                        # three years

# --------------------------------------------------- #
# Let's consider FOLDS starting every trimester       #
# --------------------------------------------------- #
    
FOLD_STRIDE = 8*91 # every 3 hrs x 8 = 24h
                   # 1 quarter = 91 days

# --------------------------------------------------- #
# Let's consider a train-test-split ratio of 2/3      #
# --------------------------------------------------- #

TRAIN_TEST_RATIO = 0.66

# %% [markdown]
# ❓ **Question (<font color="#c91ac9">FOLDS</font>)** ❓
#
# Code the function `get_folds` below that we will use to create folds  `folds = get_folds(df, FOLD_LENGTH, FOLD_STRIDE)`

# %%
def get_folds(
    df: pd.DataFrame, 
    fold_length: int,     #8*365 * 3 # every 3 hrs x 8 = 24h # three years
    fold_stride: int) -> List[pd.DataFrame]: # 8*91 # every 3 hrs x 8 = 24h # 1 quarter = 91 days
    '''
    This function slides through the Time Series dataframe of shape (n_timesteps, n_features) to create folds
    - of equal `fold_length`
    - using `fold_stride` between each fold

    Returns a list of folds, each as a DataFrame
    '''
    start_point = np.arange(0, len(df)-fold_length ,fold_stride) #len(df) = df.shape[0] = Number of rows
    folds = []
    for i in start_point:
        folds.append(df[i: i+fold_length])
        
    return folds

# %% [markdown]
# 🧪 ***Test your code***

# %%
folds = get_folds(df, FOLD_LENGTH, FOLD_STRIDE)

print(f'The function generated {len(folds)} folds.')
print(f'Each fold has a shape equal to {folds[0].shape}.')
# Out:
# The function generated 21 folds.
# Each fold has a shape equal to (8760, 19).

# %%
#folds

# %%
from nbresult import ChallengeResult

result = ChallengeResult('folds',
                         number_of_folds = len(folds),
                         fold_shape = folds[0].shape)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-6.2.5, py-1.11.0, pluggy-1.0.0 -- /home/nikkord/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/nikkord/code/nikkordalis/data-challenges/06-Deep-Learning/04-Recurrent-Neural-Networks/03-Predict-temperature
# plugins: anyio-3.4.0
# collecting ... collected 2 items
#
# tests/test_folds.py::TestFolds::test_variable_fold_shape PASSED          [ 50%]
# tests/test_folds.py::TestFolds::test_variable_number_of_folds PASSED     [100%]
#
# ============================== 2 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/folds.pickle
#
# git commit -m 'Completed folds step'
#
# git push origin master

# %% [markdown]
# ☝️ This amount of <font color="#c91ac9">**FOLDS**</font> should be enough to cross-validate our model correctly !

# %% [markdown]
# ## (1.2) Temporal <font color=blue>**Train**</font>/<font color="#ff8005">**Test**</font> Split

# %% [markdown]
# 👩🏻‍🏫 Let's focus on one fold for the moment.

# %%
fold = folds[0]
fold
# Out:
#       p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 0       996.84     -8.81    264.59        -9.66    93.5          3.13
# 1       997.71     -9.67    263.66       -10.62    92.7          2.93
# 2       999.69     -7.66    265.52        -8.84    91.2          3.43
# 3      1000.30     -6.87    266.27        -8.28    89.6          3.64
# 4       999.88     -5.69    267.48        -7.00    90.4          3.99
# ...        ...       ...       ...          ...     ...           ...
# 8755    980.34      1.45    276.18         0.03    90.2          6.79
# 8756    983.25      2.23    276.73         0.21    86.4          7.18
# 8757    985.46      1.69    276.00        -0.52    85.2          6.90
# 8758    986.63      2.16    276.38        -1.14    78.7          7.14
# 8759    987.50      1.57    275.72        -0.88    83.7          6.84
#
#       VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0             2.93          0.20       1.83             2.94       1312.18
# 1             2.71          0.21       1.69             2.72       1317.71
# 2             3.13          0.30       1.95             3.13       1310.14
# 3             3.27          0.38       2.03             3.26       1306.98
# 4             3.61          0.38       2.25             3.61       1300.51
# ...            ...           ...        ...              ...           ...
# 8755          6.12          0.67       3.89             6.24       1240.67
# 8756          6.20          0.98       3.93             6.31       1240.81
# 8757          5.88          1.02       3.72             5.97       1246.23
# 8758          5.62          1.52       3.55             5.70       1245.68
# 8759          5.73          1.12       3.61             5.80       1249.44
#
#             Wx        Wy    max Wx    max Wy       Day_sin       Day_cos  \
# 0    -0.175527  0.039879 -0.614344  0.139576  7.071068e-01  7.071068e-01
# 1    -0.041452  0.027960 -0.414519  0.279596  1.000000e+00  4.339955e-12
# 2    -0.314796 -0.128466 -0.583298 -0.238040  7.071068e-01 -7.071068e-01
# 3    -1.834577 -0.141163 -2.622249 -0.201771  6.903299e-12 -1.000000e+00
# 4    -0.825870  0.828758 -1.327039  1.331679 -7.071068e-01 -7.071068e-01
# ...        ...       ...       ...       ...           ...           ...
# 8755 -0.604351 -3.731375 -1.191115 -7.354165 -8.715574e-02 -9.961947e-01
# 8756 -0.432628 -2.126437 -0.849307 -4.174479 -7.660444e-01 -6.427876e-01
# 8757 -0.626578 -2.513066 -0.977364 -3.919995 -9.961947e-01  8.715574e-02
# 8758 -0.773266 -3.669409 -1.222791 -5.802558 -6.427876e-01  7.660444e-01
# 8759 -0.430321 -1.973632 -0.766909 -3.517364  8.715574e-02  9.961947e-01
#
#       Year_sin  Year_cos
# 0     0.011483  0.999934
# 1     0.013633  0.999907
# 2     0.015783  0.999875
# 3     0.017933  0.999839
# 4     0.020083  0.999798
# ...        ...       ...
# 8755 -0.028744  0.999587
# 8756 -0.026594  0.999646
# 8757 -0.024445  0.999701
# 8758 -0.022295  0.999751
# 8759 -0.020145  0.999797
#
# [8760 rows x 19 columns]

# %% [markdown]
# ☝️ We want to split this fold **chronologically** into:
#
# - a <font color=blue>train</font> dataframe
# - a <font color="#ff8005">test</font> dataframe
#
# that will contain all the data we need to be able to sample many `(X_i, y_i)` pairs in each dataframe in a next step!

# %% [markdown]
# The `INPUT_LENGTH` of each `X_i` is going to be equal to 2 weeks (it is quite a common period for weather forecasting)

# %%
INPUT_LENGTH = 8 * 14 # records every 3 hours x 8 = 24 hours
                      # two weeks

# %% [markdown]
# ❓ **Question (temporal <font color=blue>train</font>-<font color=orange>test</font> split)** ❓
#
# Code the function `train_test_split` down below which:
# - <i>(input)</i> given a `fold` (like above), a `train_test_ratio` (e.g 0.8) and an `input_length` (fixed)
# - <i>(output)</i> a tuple of (`fold_train`, `fold_test`) dataframes
#
#
# ❗️Hints to avoid data leakage❗️
#
# - `fold_train` last index will become the last `y_train` later on
# - `fold_test` first index will be used to create the first `X_test`
# - To avoid data leakage, `y_train_last` should be JUST before `y_test_first`
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/explanations_for_train_test_split_temporal.png" alt="train_test_split_temporal" width="500" height="500">

# %%
fold.head()
# Out:
#    p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 0    996.84     -8.81    264.59        -9.66    93.5          3.13
# 1    997.71     -9.67    263.66       -10.62    92.7          2.93
# 2    999.69     -7.66    265.52        -8.84    91.2          3.43
# 3   1000.30     -6.87    266.27        -8.28    89.6          3.64
# 4    999.88     -5.69    267.48        -7.00    90.4          3.99
#
#    VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 0          2.93          0.20       1.83             2.94       1312.18
# 1          2.71          0.21       1.69             2.72       1317.71
# 2          3.13          0.30       1.95             3.13       1310.14
# 3          3.27          0.38       2.03             3.26       1306.98
# 4          3.61          0.38       2.25             3.61       1300.51
#
#          Wx        Wy    max Wx    max Wy       Day_sin       Day_cos  \
# 0 -0.175527  0.039879 -0.614344  0.139576  7.071068e-01  7.071068e-01
# 1 -0.041452  0.027960 -0.414519  0.279596  1.000000e+00  4.339955e-12
# 2 -0.314796 -0.128466 -0.583298 -0.238040  7.071068e-01 -7.071068e-01
# 3 -1.834577 -0.141163 -2.622249 -0.201771  6.903299e-12 -1.000000e+00
# 4 -0.825870  0.828758 -1.327039  1.331679 -7.071068e-01 -7.071068e-01
#
#    Year_sin  Year_cos
# 0  0.011483  0.999934
# 1  0.013633  0.999907
# 2  0.015783  0.999875
# 3  0.017933  0.999839
# 4  0.020083  0.999798

# %%
fold.columns
# Out:
# Index(['p (mbar)', 'T (degC)', 'Tpot (K)', 'Tdew (degC)', 'rh (%)',
#        'VPmax (mbar)', 'VPact (mbar)', 'VPdef (mbar)', 'sh (g/kg)',
#        'H2OC (mmol/mol)', 'rho (g/m**3)', 'Wx', 'Wy', 'max Wx', 'max Wy',
#        'Day_sin', 'Day_cos', 'Year_sin', 'Year_cos'],
#       dtype='object')

# %%
# X = fold
# y = fold['T (degC)']

# %%
def train_test_split(fold:pd.DataFrame,
                     train_test_ratio: float,
                     input_length: int) -> Tuple[pd.DataFrame]:
    '''
    Returns a train dataframe and a test dataframe (fold_train, fold_test)
    from which one can sample (X,y) sequences.
    df_train should contain all the timesteps until round(train_test_ratio * len(fold))   
    '''
    
    fold_train = fold[:  round(train_test_ratio*len(fold))]
    fold_test =  fold[round(train_test_ratio*len(fold))-1 :]

    return fold_train, fold_test

# %% [markdown]
# 🧪 ***Test your code***

# %%
(fold_train, fold_test) = train_test_split(fold, TRAIN_TEST_RATIO, INPUT_LENGTH)

# %%
from nbresult import ChallengeResult

result = ChallengeResult('holdout',
                         train_index_start = fold_train.index.start,
                         train_index_stop = fold_train.index.stop,
                         test_index_start = fold_test.index.start,
                         test_index_stop = fold_test.index.stop)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-6.2.5, py-1.11.0, pluggy-1.0.0 -- /home/nikkord/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/nikkord/code/nikkordalis/data-challenges/06-Deep-Learning/04-Recurrent-Neural-Networks/03-Predict-temperature
# plugins: anyio-3.4.0
# collecting ... collected 4 items
#
# tests/test_holdout.py::TestHoldout::test_variable_test_index_start PASSED [ 25%]
# tests/test_holdout.py::TestHoldout::test_variable_test_index_stop PASSED [ 50%]
# tests/test_holdout.py::TestHoldout::test_variable_train_index_start PASSED [ 75%]
# tests/test_holdout.py::TestHoldout::test_variable_train_index_stop PASSED [100%]
#
# ============================== 4 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/holdout.pickle
#
# git commit -m 'Completed holdout step'
#
# git push origin master

# %% [markdown]
# ## (1.3) Create (X, y) sequences

# %% [markdown]
# Now that we have splitted our fold into a <font color="blue">train</font> set and a <font color="#ff8005">test</font> set, it is time to:
# - 🏋 sample lots of sequences $(X_i, y_i)$ on which the model will be <font color="blue">trained</font>
# - 👩🏻‍🏫 sample lots of sequences $(X_i, y_i)$ on which the model will be <font color="#ff8005">evaluated</font>
#
# <img src="https://bit.ly/3Ri8Vfd" alt="Sequences in each fold" width="300" height="300">
#
# 🎯 Our goal is to create 3D-arrays `(X_train, y_train)` and `(X_test, y_test)` containing all the SEQUENCES we need from this fold:
#
# * `X_train.shape = (n_samples_train, input_length, n_features)`
# * `y_train.shape = (n_samples_train, output_length, n_targets)`
#
# 👉 Notice that we are now dealing with **3D arrays** instead of **2D DataFrames** time-series
#
# <img src="https://bit.ly/3bOhKNj" alt="3d arrays time series" width="1200" height="800">

# %%
# INPUT X
print(f'N_FEATURES = {N_FEATURES}')
print(f'INPUT_LENGTH = {INPUT_LENGTH}')
# Out:
# N_FEATURES = 19
# INPUT_LENGTH = 112

# %% [markdown]
# ☝️ `X` is the **input** of our model.
# - It contains $19$ features: the past values of the <font color=green>**target**</font> + $18$ <font color=orange>**past-covariates**</font>
# - Each sequence has a length equal to $112$ timesteps (=$2$ weeks)

# %%
# TARGET Y
print(f'N_TARGETS = {N_TARGETS}')

# Let's only predict 1 value ahead of us
OUTPUT_LENGTH = 1
# Out:
# N_TARGETS = 1

# %% [markdown]
# ☝️ `y` is the <font color=green>**target**</font> that we want to predic:t
# - It is the value at the single next timestep (=3 hours later)
# - We could also predict `OUTPUT_LENGTH > 1`, i.e several values in the future (3 hours later, 6 hours later, 9 hours later, ...) but let's keep it simple here and just try to predict the next point (in 3 hours)

# %% [markdown]
# 💡 To create these SEQUENCES within the <font color="blue">train</font> set and the <font color="#ff8005">test</font> set, you have several options, among them:
# - 🎲 <u><i>Option 1</i></u>: creating these sequences by randomly sampling $(X_i, y_i)$ from <font color="blue">fold_train</font> and <font color="#ff8005">fold_test</font>.
# - ⌚️ <u><i>Option 2</i></u>: scanning a fold chronologically and create all the possible pairs $(X_i, y_i)$.
#
#
# 👉 Let's focus on the first option: random sampling
#
# 🎁 If you want to scan the folds chronologically, we provided the solution in the section and you can come back to it later

# %% [markdown]
# ### (1.2.1) Option 1: Create (X, y) by random sampling in each split

# %% [markdown]
# 👇 We will code:
#
# * 1️⃣ a function `get_Xi_yi` to generate a single sequence randomly from within a fold
#
# * 2️⃣ a function `get_X_y` to generate 3D-arrays containing multiple sequences from a fold, calling the first function `get_Xi_yi` many times over

# %% [markdown]
# #### (1.2.2.1) Generating one random sequence

# %% [markdown]
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/get_xi_yi.png" alt="one sequence" width="400" height="400">

# %% [markdown]
# ❓ **Question (extracting a random sequence from a fold)** ❓
#
# Code the function `get_Xi_yi` down below which:
# - <i>(input)</i> given a fold, an `input_length` and an `output_length`
# - <i>(output)</i> returns a sequence $(X_i,y_i)$

# %%
def get_Xi_yi(
    fold:pd.DataFrame, 
    input_length:int, 
    output_length:int):
    '''
    - given a fold, it returns one sequence (X_i, y_i)
    - with the starting point of the sequence being chosen at random
    '''
    pass  # YOUR CODE HERE

# %%
def get_Xi_yi(
    fold: pd.DataFrame,
    input_length: int,
    output_length: int,
    target_column: str  # Replace with the actual name of your target column
) -> Tuple[pd.DataFrame]:
    """
    Given a fold, it returns one sequence (X_i, y_i) based on the desired
    input_length and output_length with the starting point of the sequence chosen at random.

    Args:
        fold (pd.DataFrame): A single fold
        input_length (int): How long each X_i should be
        output_length (int): How long each y_i should be
        target_column (str): Name of the target column

    Returns:
        Tuple[pd.DataFrame]: A tuple of two dataframes (X_i, y_i)
    """
    # Ensure that there are enough data points in the fold
    if len(fold) < input_length + output_length:
        raise ValueError("Not enough data points in the fold for the specified input and output lengths.")

    # Randomly choose the starting point for the sequence
    start_index = np.random.randint(0, len(fold) - input_length - output_length + 1)

    # Extract X_i and y_i based on the chosen starting point
    X_i = fold.iloc[start_index:start_index + input_length, :]
    y_i = fold.iloc[start_index + input_length:start_index + input_length + output_length, [fold.columns.get_loc(target_column)]]


    return X_i, y_i

# %% [markdown]
# 🧪 ***Test your code below***

# %%
X_train_i, y_train_i = get_Xi_yi(fold_train, INPUT_LENGTH, OUTPUT_LENGTH,TARGET)
X_test_i, y_test_i = get_Xi_yi(fold_test, INPUT_LENGTH, OUTPUT_LENGTH,TARGET)

# %%
from nbresult import ChallengeResult

result = ChallengeResult('sequence',
                         x_train_i_shape = X_train_i.shape,
                         y_train_i_shape = y_train_i.shape,
                         x_test_i_shape = X_test_i.shape,
                         y_test_i_shape = y_test_i.shape)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-6.2.5, py-1.11.0, pluggy-1.0.0 -- /home/nikkord/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/nikkord/code/nikkordalis/data-challenges/06-Deep-Learning/04-Recurrent-Neural-Networks/03-Predict-temperature
# plugins: anyio-3.4.0
# collecting ... collected 4 items
#
# tests/test_sequence.py::TestSequence::test_variable_x_test_i_shape PASSED [ 25%]
# tests/test_sequence.py::TestSequence::test_variable_x_train_i_shape PASSED [ 50%]
# tests/test_sequence.py::TestSequence::test_variable_y_test_i_shape PASSED [ 75%]
# tests/test_sequence.py::TestSequence::test_variable_y_train_i_shape PASSED [100%]
#
# ============================== 4 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/sequence.pickle
#
# git commit -m 'Completed sequence step'
#
# git push origin master

# %%
# Advanced check 😈 
# You should not allow some truncated (X_i,y_i) pairs to be generating,
# should you start sampling too close from the end of the fold... !

X_last, y_last = get_Xi_yi(fold_test, input_length=len(fold_test)-1, output_length=OUTPUT_LENGTH,target_column=TARGET)
assert y_last.values == fold_test.iloc[-1,:][TARGET]

# %% [markdown]
# #### (1.2.2.2) Generating multiple random sequences

# %% [markdown]
# <img src="https://bit.ly/3Ri8Vfd" alt="Sequences in each fold" width="500" height="500">

# %% [markdown]
# ❓ **Question (extracting multiple random sequence from a fold)** ❓
#
# Code the function `get_X_y` down below which:
# - <i>(input)</i> given a fold, a `number_of_sequences` an `input_length` and an `output_length`
# - <i>(output)</i> returns $(X,y)$
#
# _Don't forget to use the `get_Xi_yi` function that you have just coded!_

# %%
def get_X_y(
    fold:pd.DataFrame,
    number_of_sequences:int,
    input_length:int,
    output_length:int
):
    pass  # YOUR CODE HERE

# %%
def get_X_y(
    fold: pd.DataFrame,
    number_of_sequences: int,
    input_length: int,
    output_length: int,
    target_column: str  # Replace with the actual name of your target column
) -> Tuple[np.ndarray]:
    """
    Given a fold, it returns multiple sequences (X, y) based on the desired
    input_length, output_length, and the number of sequences.

    Args:
        fold (pd.DataFrame): A single fold
        number_of_sequences (int): Number of sequences to generate
        input_length (int): How long each X_i should be
        output_length (int): How long each y_i should be
        target_column (str): Name of the target column

    Returns:
        Tuple[np.ndarray]: A tuple of 3D arrays (X, y)
    """
    X_list = []
    y_list = []

    for _ in range(number_of_sequences):
        X_i, y_i = get_Xi_yi(fold, input_length, output_length, target_column)
        X_list.append(X_i.values)  # Append the values of X_i as a 2D numpy array
        y_list.append(y_i.values)  # Append the values of y_i as a 1D numpy array

    # Convert the lists to numpy arrays
    X = np.array(X_list)
    y = np.array(y_list)

    return X, y

# %% [markdown]
# 🧪 ***Test your code***

# %%
N_TRAIN = 6666 # number_of_sequences_train
N_TEST =  3333 # number_of_sequences_test

X_train, y_train = get_X_y(fold_train, N_TRAIN, INPUT_LENGTH, OUTPUT_LENGTH,TARGET)
X_test, y_test = get_X_y(fold_test, N_TEST, INPUT_LENGTH, OUTPUT_LENGTH,TARGET)

# %%
from nbresult import ChallengeResult

result = ChallengeResult('multiple_sequences',
                         x_train_shape = X_train.shape,
                         y_train_shape = y_train.shape,
                         x_test_shape = X_test.shape,
                         y_test_shape = y_test.shape)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-6.2.5, py-1.11.0, pluggy-1.0.0 -- /home/nikkord/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /home/nikkord/code/nikkordalis/data-challenges/06-Deep-Learning/04-Recurrent-Neural-Networks/03-Predict-temperature
# plugins: anyio-3.4.0
# collecting ... collected 4 items
#
# tests/test_multiple_sequences.py::TestMultipleSequences::test_variable_x_test_i_shape PASSED [ 25%]
# tests/test_multiple_sequences.py::TestMultipleSequences::test_variable_x_train_shape PASSED [ 50%]
# tests/test_multiple_sequences.py::TestMultipleSequences::test_variable_y_test_i_shape PASSED [ 75%]
# tests/test_multiple_sequences.py::TestMultipleSequences::test_variable_y_train_shape PASSED [100%]
#
# ============================== 4 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/multiple_sequences.pickle
#
# git commit -m 'Completed multiple_sequences step'
#
# git push origin master

# %% [markdown]
# ### (1.2.2) (Don't read this now, keep for later) 🎁 Option 2: Scanning  chronologically

# %% [markdown]
# As stated earlier, there are multiple ways to extract sequences from a fold.
#
# - 🎲 In the previous section, you coded:
#     - `get_Xi_yi` which randomly samples _one_ sequence
#     - and `get_X_y` which randomly generates _multiple_ sequences
#
# - ⌚️ In this section, we provide you a unique function `get_X_y_strides`.
#     - It scans a fold chronologically based on:
#          - an `input_length` (let's still use `INPUT_LENGTH = 8 * 14`, i.e. two weeks)
#          - and a `sequence_stride` (think about a one-dimensional convolutional operation!)

# %% [markdown]
# 👉 Let's scan the fold with a temporal stride of 3 hours (the minimum one):

# %%
SEQUENCE_STRIDE = 1

# %%
def get_X_y_strides(fold: pd.DataFrame, input_length: int, output_length: int, sequence_stride: int):
    '''
    - slides through a `fold` Time Series (2D array) to create sequences of equal
        * `input_length` for X,
        * `output_length` for y,
    using a temporal gap `sequence_stride` between each sequence
    - returns a list of sequences, each as a 2D-array time series
    '''

    X, y = [], []

    for i in range(0, len(fold), sequence_stride):
        # Exits the loop as soon as the last fold index would exceed the last index
        if (i + input_length + output_length) > len(fold):
            break
        X_i = fold.iloc[i:i + input_length, :]
        y_i = fold.iloc[i + input_length:i + input_length + output_length, :][[TARGET]]
        X.append(X_i)
        y.append(y_i)

    return np.array(X), np.array(y)

# %% [markdown]
# 🧑🏻‍🎓 Some clarifications about scanning a fold sequentially :

# %%
print("FOLD_LENGTH") 
print(f"= {FOLD_LENGTH} timesteps")
print(f"= {int(FOLD_LENGTH/8)} days") # 8 records per day, every 3 hours
print(f"= {int(FOLD_LENGTH/8/7)} weeks")
# Out:
# FOLD_LENGTH
# = 8760 timesteps
# = 1095 days
# = 156 weeks

# %%
X_train, y_train = get_X_y_strides(fold_train, INPUT_LENGTH, OUTPUT_LENGTH, SEQUENCE_STRIDE)
X_test, y_test = get_X_y_strides(fold_test, INPUT_LENGTH, OUTPUT_LENGTH, SEQUENCE_STRIDE)

print(X_train.shape)
print(y_train.shape)
# Out:
# (5670, 112, 19)
# (5670, 1, 1)

# %% [markdown]
# 👇 Illustration down below if *SEQUENCE_STRIDE = 1 week*
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/scanning_a_time_series_chronologically_v3.png">

# %% [markdown]
# # (2) Modelling

# %% [markdown]
# **The MAE as a metrics to monitor the temperature prediction**

# %% [markdown]
# The Mean Absolute Error seems to be a reasonable metrics to evaluate a model's capability to predict the temperature:
#
# $$ MAE = \frac{1}{n_{samples}} \times \sum_{i = 1}^{n_{samples}} |y_{true}^{(i)} - y_{pred}^{(i)}|$$

# %% [markdown]
# ## (2.1) A Recurrent Neural Network: the `LSTM`
#
# 🚀 It is time to design a Recurrent Neural Network and hopefully beat the baseline 💪 !

# %% [markdown]
# ❓ **Question (RNN)** ❓
#
# - Create a function `init_model` which builds and compiles a simple Recurrent Neural Network with an LSTM layer
# - Don't forget to normalize your data with a [📚 Normalization layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Normalization)

# %%
from tensorflow.keras import models, layers, optimizers, metrics
from tensorflow.keras.layers.experimental.preprocessing import Normalization
from tensorflow.keras.models import Sequential

def init_model(input_shape):
    model = models.Sequential()

    # Normalization layer
    normalization_layer = Normalization()
    normalization_layer.adapt(X_train)

    # LSTM layers
    model.add(layers.LSTM(64, input_shape=input_shape, activation='relu', return_sequences=True))
    model.add(layers.LSTM(32, activation='relu', return_sequences=True))
    
    # Output layer
    model.add(layers.Dense(1, activation='linear'))

    # Compile the model
    model.compile(optimizer=optimizers.Adam(learning_rate=0.0001),
                  loss='mae',
                  metrics=[metrics.MeanAbsoluteError()])

    return model

# Assuming X_train shape is (n_samples_train, input_length, n_features)
input_shape = X_train.shape[1:]
model = init_model(input_shape)
# Out:
# 2024-01-15 21:34:47.846264: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2024-01-15 21:34:47.846422: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-01-15 21:34:47.846497: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (LAPTOP-93FH710P): /proc/driver/nvidia/version does not exist
# 2024-01-15 21:34:47.847099: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 112, 64)           21504
#
#  lstm_1 (LSTM)               (None, 112, 32)           12416
#
#  dense (Dense)               (None, 112, 1)            33
#
# =================================================================
# Total params: 33,953
# Trainable params: 33,953
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 🛠 🎁 📉 We coded a function `plot_history` for you to visualize the training of your RNN over epochs. This function shows both the evolution of the loss function (MSE) and metrics (MAE).

# %%
def plot_history(history):
    
    fig, ax = plt.subplots(1,2, figsize=(20,7))
    # --- LOSS: MSE --- 
    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])
    ax[0].set_title('MSE')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(['Train', 'Test'], loc='best')
    ax[0].grid(axis="x",linewidth=0.5)
    ax[0].grid(axis="y",linewidth=0.5)
    
    # --- METRICS:MAE ---
    
    ax[1].plot(history.history['mae'])
    ax[1].plot(history.history['val_mae'])
    ax[1].set_title('MAE')
    ax[1].set_ylabel('MAE')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Test'], loc='best')
    ax[1].grid(axis="x",linewidth=0.5)
    ax[1].grid(axis="y",linewidth=0.5)
                        
    return ax

# %% [markdown]
# ❓ **Questions (training and evaluating)** ❓
#
# - Code the `fit_model()` method that
#     - <i>(input)</i> given `model`
#     - <i>(output)</i> returns the fitted model through a tuple `(model, history)`
# - Then:
#     - Initialize an RNN model with the `init_model` function
#     - <font color=blue>Train</font> the model
#     - <font color=orange>Evaluate</font> it on the test set

# %%
def fit_model(model, X_train, y_train, X_test, y_test, epochs=50, batch_size=64):
    """
    Train and evaluate the given model.

    Args:
        model: The RNN model to train and evaluate.
        X_train: The training input data.
        y_train: The training target data.
        X_test: The test input data.
        y_test: The test target data.
        epochs (int): Number of training epochs.
        batch_size (int): Batch size for training.

    Returns:
        Tuple: A tuple containing the trained model and its training history.
    """
    # Train the model
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test))

    # Evaluate the model on the test set
    evaluation = model.evaluate(X_test, y_test)

    print(f"\nTest Loss: {evaluation[0]}")
    print(f"Test MAE: {evaluation[1]}")

    return model, history

# %%
# %%time
# Initialize an RNN model
input_shape = X_train.shape[1:]
model = init_model(input_shape)

# Fit the model
trained_model, history = fit_model(model, X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/50
# 89/89 [==============================] - 11s 104ms/step - loss: 634.9786 - mean_absolute_error: 634.9786 - val_loss: 436.4196 - val_mean_absolute_error: 436.4196
# Epoch 2/50
# 89/89 [==============================] - 9s 101ms/step - loss: 434.5324 - mean_absolute_error: 434.5325 - val_loss: 477.5073 - val_mean_absolute_error: 477.5074
# Epoch 3/50
# 89/89 [==============================] - 9s 101ms/step - loss: 417.0471 - mean_absolute_error: 417.0472 - val_loss: 456.5986 - val_mean_absolute_error: 456.5986
# Epoch 4/50
# 89/89 [==============================] - 9s 101ms/step - loss: 495.4712 - mean_absolute_error: 495.4712 - val_loss: 512.7267 - val_mean_absolute_error: 512.7266
# Epoch 5/50
# 89/89 [==============================] - 12s 132ms/step - loss: 539.2715 - mean_absolute_error: 539.2714 - val_loss: 477.4410 - val_mean_absolute_error: 477.4410
# Epoch 6/50
# 89/89 [==============================] - 12s 136ms/step - loss: 479.0383 - mean_absolute_error: 479.0382 - val_loss: 443.0397 - val_mean_absolute_error: 443.0398
# Epoch 7/50
# 89/89 [==============================] - 12s 137ms/step - loss: 450.7178 - mean_absolute_error: 450.7177 - val_loss: 451.7789 - val_mean_absolute_error: 451.7789
# Epoch 8/50
# 89/89 [==============================] - 12s 139ms/step - loss: 404.4704 - mean_absolute_error: 404.4704 - val_loss: 313.0936 - val_mean_absolute_error: 313.0937
# Epoch 9/50
# 89/89 [==============================] - 13s 141ms/step - loss: 293.5372 - mean_absolute_error: 293.5373 - val_loss: 267.6656 - val_mean_absolute_error: 267.6656
# Epoch 10/50
# 89/89 [==============================] - 13s 145ms/step - loss: 314.1352 - mean_absolute_error: 314.1352 - val_loss: 349.0651 - val_mean_absolute_error: 349.0650
# Epoch 11/50
# 89/89 [==============================] - 14s 152ms/step - loss: 218.2621 - mean_absolute_error: 218.2621 - val_loss: 105.8111 - val_mean_absolute_error: 105.8111
# Epoch 12/50
# 89/89 [==============================] - 16s 175ms/step - loss: 86.6206 - mean_absolute_error: 86.6206 - val_loss: 88.9621 - val_mean_absolute_error: 88.9621
# Epoch 13/50
# 89/89 [==============================] - 17s 190ms/step - loss: 80.2707 - mean_absolute_error: 80.2706 - val_loss: 78.2202 - val_mean_absolute_error: 78.2202
# Epoch 14/50
# 89/89 [==============================] - 20s 220ms/step - loss: 72.8543 - mean_absolute_error: 72.8543 - val_loss: 68.1282 - val_mean_absolute_error: 68.1282
# Epoch 15/50
# 89/89 [==============================] - 16s 184ms/step - loss: 68.5939 - mean_absolute_error: 68.5939 - val_loss: 81.3468 - val_mean_absolute_error: 81.3468
# Epoch 16/50
# 89/89 [==============================] - 17s 192ms/step - loss: 80.2049 - mean_absolute_error: 80.2049 - val_loss: 77.5607 - val_mean_absolute_error: 77.5607
# Epoch 17/50
# 89/89 [==============================] - 17s 192ms/step - loss: 73.7459 - mean_absolute_error: 73.7459 - val_loss: 69.7472 - val_mean_absolute_error: 69.7472
# Epoch 18/50
# 89/89 [==============================] - 16s 182ms/step - loss: 67.3467 - mean_absolute_error: 67.3467 - val_loss: 62.9237 - val_mean_absolute_error: 62.9237
# Epoch 19/50
# 89/89 [==============================] - 16s 181ms/step - loss: 60.2787 - mean_absolute_error: 60.2787 - val_loss: 56.8250 - val_mean_absolute_error: 56.8250
# Epoch 20/50
# 89/89 [==============================] - 20s 222ms/step - loss: 52.6342 - mean_absolute_error: 52.6342 - val_loss: 48.6737 - val_mean_absolute_error: 48.6738
# Epoch 21/50
# 89/89 [==============================] - 18s 203ms/step - loss: 46.4983 - mean_absolute_error: 46.4983 - val_loss: 43.1860 - val_mean_absolute_error: 43.1860
# Epoch 22/50
# 89/89 [==============================] - 17s 196ms/step - loss: 56.3044 - mean_absolute_error: 56.3044 - val_loss: 89.5566 - val_mean_absolute_error: 89.5566
# Epoch 23/50
# 89/89 [==============================] - 17s 194ms/step - loss: 60.5222 - mean_absolute_error: 60.5222 - val_loss: 45.3827 - val_mean_absolute_error: 45.3827
# Epoch 24/50
# 89/89 [==============================] - 19s 216ms/step - loss: 47.7905 - mean_absolute_error: 47.7905 - val_loss: 40.1032 - val_mean_absolute_error: 40.1032
# Epoch 25/50
# 89/89 [==============================] - 18s 204ms/step - loss: 40.7962 - mean_absolute_error: 40.7962 - val_loss: 36.5341 - val_mean_absolute_error: 36.5341
# Epoch 26/50
# 89/89 [==============================] - 18s 200ms/step - loss: 35.8481 - mean_absolute_error: 35.8481 - val_loss: 33.2597 - val_mean_absolute_error: 33.2597
# Epoch 27/50
# 89/89 [==============================] - 17s 195ms/step - loss: 32.0774 - mean_absolute_error: 32.0774 - val_loss: 28.3859 - val_mean_absolute_error: 28.3859
# Epoch 28/50
# 89/89 [==============================] - 17s 193ms/step - loss: 36.9283 - mean_absolute_error: 36.9283 - val_loss: 29.2192 - val_mean_absolute_error: 29.2192
# Epoch 29/50
# 89/89 [==============================] - 16s 183ms/step - loss: 28.5525 - mean_absolute_error: 28.5525 - val_loss: 26.3357 - val_mean_absolute_error: 26.3357
# Epoch 30/50
# 89/89 [==============================] - 17s 186ms/step - loss: 26.5794 - mean_absolute_error: 26.5794 - val_loss: 25.1143 - val_mean_absolute_error: 25.1143
# Epoch 31/50
# 89/89 [==============================] - 16s 183ms/step - loss: 24.9970 - mean_absolute_error: 24.9970 - val_loss: 23.7929 - val_mean_absolute_error: 23.7929
# Epoch 32/50
# 89/89 [==============================] - 17s 190ms/step - loss: 23.7744 - mean_absolute_error: 23.7744 - val_loss: 22.4256 - val_mean_absolute_error: 22.4256
# Epoch 33/50
# 89/89 [==============================] - 16s 184ms/step - loss: 22.4204 - mean_absolute_error: 22.4204 - val_loss: 21.8379 - val_mean_absolute_error: 21.8379
# Epoch 34/50
# 89/89 [==============================] - 17s 191ms/step - loss: 20.9309 - mean_absolute_error: 20.9309 - val_loss: 20.1227 - val_mean_absolute_error: 20.1227
# Epoch 35/50
# 89/89 [==============================] - 16s 181ms/step - loss: 19.5733 - mean_absolute_error: 19.5733 - val_loss: 18.7609 - val_mean_absolute_error: 18.7609
# Epoch 36/50
# 89/89 [==============================] - 16s 182ms/step - loss: 17.8596 - mean_absolute_error: 17.8596 - val_loss: 17.7005 - val_mean_absolute_error: 17.7005
# Epoch 37/50
# 89/89 [==============================] - 17s 188ms/step - loss: 172.3767 - mean_absolute_error: 172.3767 - val_loss: 1371.4321 - val_mean_absolute_error: 1371.4321
# Epoch 38/50
# 89/89 [==============================] - 16s 175ms/step - loss: 2724.0789 - mean_absolute_error: 2724.0781 - val_loss: 2761.5183 - val_mean_absolute_error: 2761.5183
# Epoch 39/50
# 89/89 [==============================] - 18s 208ms/step - loss: 2668.4951 - mean_absolute_error: 2668.4963 - val_loss: 5219.2285 - val_mean_absolute_error: 5219.2271
# Epoch 40/50
# 89/89 [==============================] - 18s 207ms/step - loss: 14472.2441 - mean_absolute_error: 14472.2432 - val_loss: 336.8359 - val_mean_absolute_error: 336.8359
# Epoch 41/50
# 89/89 [==============================] - 19s 210ms/step - loss: 1016.1487 - mean_absolute_error: 1016.1492 - val_loss: 988.8986 - val_mean_absolute_error: 988.8984
# Epoch 42/50
# 89/89 [==============================] - 17s 188ms/step - loss: 1878.0300 - mean_absolute_error: 1878.0305 - val_loss: 1683.7780 - val_mean_absolute_error: 1683.7777
# Epoch 43/50
# 89/89 [==============================] - 18s 197ms/step - loss: 2816.3865 - mean_absolute_error: 2816.3860 - val_loss: 3073.0510 - val_mean_absolute_error: 3073.0513
# Epoch 44/50
# 89/89 [==============================] - 18s 198ms/step - loss: 3775.7542 - mean_absolute_error: 3775.7544 - val_loss: 3354.6331 - val_mean_absolute_error: 3354.6338
# Epoch 45/50
# 89/89 [==============================] - 19s 212ms/step - loss: 1875.0239 - mean_absolute_error: 1875.0238 - val_loss: 1338.5687 - val_mean_absolute_error: 1338.5688
# Epoch 46/50
# 89/89 [==============================] - 20s 218ms/step - loss: 1814.4083 - mean_absolute_error: 1814.4081 - val_loss: 2521.0750 - val_mean_absolute_error: 2521.0752
# Epoch 47/50
# 89/89 [==============================] - 19s 213ms/step - loss: 1448.1530 - mean_absolute_error: 1448.1531 - val_loss: 1179.0709 - val_mean_absolute_error: 1179.0710
# Epoch 48/50
# 89/89 [==============================] - 17s 194ms/step - loss: 1061.7943 - mean_absolute_error: 1061.7946 - val_loss: 507.5868 - val_mean_absolute_error: 507.5868
# Epoch 49/50
# 89/89 [==============================] - 18s 201ms/step - loss: 829.0043 - mean_absolute_error: 829.0043 - val_loss: 315.0112 - val_mean_absolute_error: 315.0112
# Epoch 50/50
# 89/89 [==============================] - 19s 216ms/step - loss: 99.2180 - mean_absolute_error: 99.2180 - val_loss: 79.1541 - val_mean_absolute_error: 79.1541
# 90/90 [==============================] - 5s 51ms/step - loss: 79.1541 - mean_absolute_error: 79.1541
#
# Test Loss: 79.15412139892578
# Test MAE: 79.15412139892578
# CPU times: user 37min 23s, sys: 17min 38s, total: 55min 2s
# Wall time: 13min 30s

# %%
# Make predictions on the test set
predictions = trained_model.predict(X_test)

# Now 'predictions' contains the model's predictions for each time step
# You can compare these predictions with the actual values in 'y_test'

# Example: Print the first 5 predictions and actual values
print("Predictions:")
print(predictions[:5])

print("\nActual Values:")
print(y_test[:5])
# Out:
# Predictions:
# [[[ -0.2644155 ]
#   [ -0.20860004]
#   [  7.9619813 ]
#   [  7.7750673 ]
#   [  8.814183  ]
#   [  8.097503  ]
#   [  8.442323  ]
#   [  9.09915   ]
#   [ 16.48159   ]
#   [ 44.857037  ]
#   [-11.616562  ]
#   [-11.234513  ]
#   [-13.296581  ]
#   [ 10.036568  ]
#   [ 20.626822  ]
#   [ 11.836117  ]
#   [ 16.192553  ]
#   [ 15.602056  ]
#   [ 18.565758  ]
#   [  8.79715   ]
#   [ 12.456005  ]
#   [  8.4078045 ]
#   [ 12.432686  ]
#   [  8.571491  ]
#   [ 12.418205  ]
#   [  8.591574  ]
#   [ 12.418331  ]
#   [  8.796625  ]
#   [ 12.402094  ]
#   [  8.746416  ]
#   [ 12.419824  ]
#   [  8.791887  ]
#   [ 12.416553  ]
#   [  8.638966  ]
#   [ 12.432596  ]
#   [  8.747805  ]
#   [ 12.419425  ]
#   [  8.821665  ]
#   [ 12.418083  ]
#   [  8.692743  ]
#   [ 12.40395   ]
#   [  8.572992  ]
#   [ 12.424045  ]
#   [  8.575924  ]
#   [ 12.815045  ]
#   [  8.514812  ]
#   [ 12.479956  ]
#   [  7.828483  ]
#   [ 12.810344  ]
#   [  8.576876  ]
#   [ 12.513851  ]
#   [  8.608343  ]
#   [ 12.45812   ]
#   [  8.637741  ]
#   [ 12.413889  ]
#   [  8.772602  ]
#   [ 12.400791  ]
#   [  8.69528   ]
#   [ 12.411913  ]
#   [  8.745941  ]
#   [ 12.403402  ]
#   [  8.87425   ]
#   [ 12.409948  ]
#   [  8.843788  ]
#   [ 12.420297  ]
#   [  8.868471  ]
#   [ 12.404854  ]
#   [  8.818022  ]
#   [ 12.424208  ]
#   [  8.901154  ]
#   [ 12.430341  ]
#   [  8.962252  ]
#   [ 12.408268  ]
#   [  8.906208  ]
#   [ 12.421472  ]
#   [  8.758047  ]
#   [ 12.429169  ]
#   [  8.766699  ]
#   [ 12.433685  ]
#   [  8.312977  ]
#   [ 12.466118  ]
#   [  8.559059  ]
#   [ 12.445625  ]
#   [  8.720158  ]
#   [ 12.424535  ]
#   [  8.7276325 ]
#   [ 12.441436  ]
#   [  8.267839  ]
#   [ 12.458275  ]
#   [  8.804562  ]
#   [ 12.411943  ]
#   [  8.845594  ]
#   [ 12.3920765 ]
#   [  8.842682  ]
#   [ 12.418462  ]
#   [  8.206717  ]
#   [ 12.45851   ]
#   [  8.826918  ]
#   [ 12.392869  ]
#   [  8.749716  ]
#   [ 12.407082  ]
#   [  8.683704  ]
#   [ 12.425757  ]
#   [  8.371061  ]
#   [ 12.446995  ]
#   [  8.702772  ]
#   [ 12.438375  ]
#   [  8.263962  ]
#   [ 12.492333  ]
#   [  8.92564   ]
#   [ 12.444171  ]
#   [  9.091469  ]]
#
#  [[ -0.26516142]
#   [ -0.22415754]
#   [  7.96952   ]
#   [  7.7785096 ]
#   [  8.746727  ]
#   [  8.0842495 ]
#   [  8.414077  ]
#   [  9.106994  ]
#   [ 17.152029  ]
#   [ 45.85095   ]
#   [-11.75239   ]
#   [-11.297909  ]
#   [-13.422183  ]
#   [ 10.066038  ]
#   [ 20.656197  ]
#   [ 19.661257  ]
#   [ 18.74249   ]
#   [ 23.970915  ]
#   [ 13.901796  ]
#   [ 17.392708  ]
#   [ 13.833168  ]
#   [ 17.33193   ]
#   [ 13.984156  ]
#   [ 17.325724  ]
#   [ 13.986891  ]
#   [ 17.326508  ]
#   [ 14.029501  ]
#   [ 17.323599  ]
#   [ 14.06852   ]
#   [ 17.337542  ]
#   [ 14.119408  ]
#   [ 17.334343  ]
#   [ 14.079895  ]
#   [ 17.340178  ]
#   [ 14.098526  ]
#   [ 17.33579   ]
#   [ 14.096643  ]
#   [ 17.339632  ]
#   [ 14.010574  ]
#   [ 17.311594  ]
#   [ 13.918955  ]
#   [ 17.316467  ]
#   [ 13.872942  ]
#   [ 17.35481   ]
#   [ 13.75279   ]
#   [ 17.331099  ]
#   [ 13.59321   ]
#   [ 17.380201  ]
#   [ 13.796062  ]
#   [ 17.326748  ]
#   [ 13.848619  ]
#   [ 17.319033  ]
#   [ 13.906618  ]
#   [ 17.317926  ]
#   [ 14.028849  ]
#   [ 17.318956  ]
#   [ 13.948566  ]
#   [ 17.311989  ]
#   [ 13.999197  ]
#   [ 17.32084   ]
#   [ 14.10532   ]
#   [ 17.336786  ]
#   [ 14.18722   ]
#   [ 17.338541  ]
#   [ 14.158176  ]
#   [ 17.32752   ]
#   [ 14.118944  ]
#   [ 17.344099  ]
#   [ 14.191257  ]
#   [ 17.352446  ]
#   [ 14.2271385 ]
#   [ 17.337496  ]
#   [ 14.195154  ]
#   [ 17.343845  ]
#   [ 14.1301155 ]
#   [ 17.343433  ]
#   [ 14.138569  ]
#   [ 17.347435  ]
#   [ 14.013084  ]
#   [ 17.349783  ]
#   [ 14.058556  ]
#   [ 17.347342  ]
#   [ 14.115149  ]
#   [ 17.337276  ]
#   [ 14.1201725 ]
#   [ 17.35276   ]
#   [ 13.984743  ]
#   [ 17.340593  ]
#   [ 14.079166  ]
#   [ 17.333635  ]
#   [ 14.076145  ]
#   [ 17.31531   ]
#   [ 14.038481  ]
#   [ 17.343346  ]
#   [ 13.956959  ]
#   [ 17.337814  ]
#   [ 14.01453   ]
#   [ 17.312258  ]
#   [ 14.000023  ]
#   [ 17.328264  ]
#   [ 13.960279  ]
#   [ 17.345976  ]
#   [ 13.937962  ]
#   [ 17.342485  ]
#   [ 13.983725  ]
#   [ 17.357641  ]
#   [ 13.959532  ]
#   [ 17.376553  ]
#   [ 14.189095  ]
#   [ 17.370571  ]
#   [ 14.302053  ]
#   [ 17.36895   ]]
#
#  [[ -0.26611063]
#   [ -0.23098248]
#   [  7.9791102 ]
#   [  7.7856026 ]
#   [  8.618466  ]
#   [  8.039053  ]
#   [  8.40451   ]
#   [  9.136076  ]
#   [ 17.756208  ]
#   [ 47.072697  ]
#   [-11.8594675 ]
#   [-11.33239   ]
#   [-13.418546  ]
#   [ 10.003541  ]
#   [ 20.483862  ]
#   [ 16.283194  ]
#   [ 17.788372  ]
#   [ 21.5534    ]
#   [ 11.836103  ]
#   [ 15.272912  ]
#   [ 11.72411   ]
#   [ 15.220971  ]
#   [ 11.8758545 ]
#   [ 15.208053  ]
#   [ 11.811665  ]
#   [ 15.207653  ]
#   [ 11.921375  ]
#   [ 15.20906   ]
#   [ 11.921352  ]
#   [ 15.221753  ]
#   [ 11.939537  ]
#   [ 15.221987  ]
#   [ 11.975702  ]
#   [ 15.217794  ]
#   [ 11.964018  ]
#   [ 15.213121  ]
#   [ 11.556065  ]
#   [ 15.235748  ]
#   [ 11.818323  ]
#   [ 15.199462  ]
#   [ 11.8157425 ]
#   [ 15.21572   ]
#   [ 11.657776  ]
#   [ 15.334146  ]
#   [ 11.674707  ]
#   [ 15.214428  ]
#   [ 11.6519165 ]
#   [ 15.238323  ]
#   [ 11.703083  ]
#   [ 15.213123  ]
#   [ 11.7524185 ]
#   [ 15.204833  ]
#   [ 11.829716  ]
#   [ 15.206133  ]
#   [ 11.930897  ]
#   [ 15.187973  ]
#   [ 11.816072  ]
#   [ 15.2052355 ]
#   [ 11.928741  ]
#   [ 15.206134  ]
#   [ 12.066227  ]
#   [ 15.218971  ]
#   [ 12.03698   ]
#   [ 15.216328  ]
#   [ 11.991961  ]
#   [ 15.217259  ]
#   [ 11.954025  ]
#   [ 15.235095  ]
#   [ 12.056505  ]
#   [ 15.226927  ]
#   [ 12.097574  ]
#   [ 15.215692  ]
#   [ 11.995615  ]
#   [ 15.224079  ]
#   [ 11.947292  ]
#   [ 15.2283125 ]
#   [ 11.894123  ]
#   [ 15.240538  ]
#   [ 11.934998  ]
#   [ 15.228386  ]
#   [ 11.931007  ]
#   [ 15.227713  ]
#   [ 11.994238  ]
#   [ 15.221044  ]
#   [ 11.706917  ]
#   [ 15.253689  ]
#   [ 11.917351  ]
#   [ 15.215193  ]
#   [ 11.94433   ]
#   [ 15.207046  ]
#   [ 11.930719  ]
#   [ 15.1984625 ]
#   [ 11.838913  ]
#   [ 15.2419195 ]
#   [ 11.870604  ]
#   [ 15.200629  ]
#   [ 11.897881  ]
#   [ 15.205507  ]
#   [ 11.850204  ]
#   [ 15.202003  ]
#   [ 11.714516  ]
#   [ 15.236986  ]
#   [ 11.800447  ]
#   [ 15.219126  ]
#   [ 11.796762  ]
#   [ 15.258746  ]
#   [ 11.952848  ]
#   [ 15.247906  ]
#   [ 12.118252  ]
#   [ 15.252345  ]
#   [ 12.183289  ]
#   [ 15.252105  ]]
#
#  [[ -0.2661538 ]
#   [ -0.22732112]
#   [  8.016831  ]
#   [  7.796677  ]
#   [  8.114332  ]
#   [  7.9485574 ]
#   [  8.380457  ]
#   [  9.340339  ]
#   [ 18.76624   ]
#   [ 47.627018  ]
#   [-11.993301  ]
#   [-11.400232  ]
#   [-13.511977  ]
#   [  9.779375  ]
#   [ 20.280989  ]
#   [  9.676439  ]
#   [ 17.389824  ]
#   [ 17.549988  ]
#   [  9.37015   ]
#   [ 12.18491   ]
#   [  9.394327  ]
#   [ 12.114077  ]
#   [  9.478031  ]
#   [ 12.105024  ]
#   [  9.597099  ]
#   [ 12.120655  ]
#   [  9.472599  ]
#   [ 12.122894  ]
#   [  9.505537  ]
#   [ 12.122757  ]
#   [  9.492121  ]
#   [ 12.1331005 ]
#   [  9.468796  ]
#   [ 12.132578  ]
#   [  9.464912  ]
#   [ 12.11186   ]
#   [  9.407772  ]
#   [ 12.096867  ]
#   [  9.604631  ]
#   [ 12.094543  ]
#   [  9.505838  ]
#   [ 12.074749  ]
#   [  9.486444  ]
#   [ 12.091103  ]
#   [  9.107809  ]
#   [ 12.087973  ]
#   [  9.581326  ]
#   [ 12.082781  ]
#   [  9.655935  ]
#   [ 12.086792  ]
#   [  9.576639  ]
#   [ 12.097816  ]
#   [  9.565054  ]
#   [ 12.119129  ]
#   [  9.657127  ]
#   [ 12.094381  ]
#   [  9.605928  ]
#   [ 12.121576  ]
#   [  9.590729  ]
#   [ 12.163351  ]
#   [  9.54365   ]
#   [ 12.143753  ]
#   [  9.536289  ]
#   [ 12.138622  ]
#   [  9.516022  ]
#   [ 12.130707  ]
#   [  9.553724  ]
#   [ 12.147137  ]
#   [  9.567274  ]
#   [ 12.1947155 ]
#   [  9.5464115 ]
#   [ 12.137337  ]
#   [  9.487724  ]
#   [ 12.128441  ]
#   [  9.494268  ]
#   [ 12.125593  ]
#   [  9.422354  ]
#   [ 12.126963  ]
#   [  9.442461  ]
#   [ 12.127428  ]
#   [  9.479279  ]
#   [ 12.136019  ]
#   [  9.482183  ]
#   [ 12.12438   ]
#   [  9.39806   ]
#   [ 12.122919  ]
#   [  9.497749  ]
#   [ 12.132046  ]
#   [  9.555532  ]
#   [ 12.138855  ]
#   [  9.61911   ]
#   [ 12.122961  ]
#   [  9.377731  ]
#   [ 12.119467  ]
#   [  9.575119  ]
#   [ 12.128765  ]
#   [  9.53373   ]
#   [ 12.119114  ]
#   [  9.410131  ]
#   [ 12.120556  ]
#   [  9.344507  ]
#   [ 12.119123  ]
#   [  9.447189  ]
#   [ 12.133959  ]
#   [  9.3713455 ]
#   [ 12.155674  ]
#   [  9.533213  ]
#   [ 12.195143  ]
#   [  9.63002   ]
#   [ 12.262789  ]
#   [  9.656162  ]
#   [ 12.23119   ]]
#
#  [[ -0.26570657]
#   [ -0.23178864]
#   [  7.9566464 ]
#   [  7.768172  ]
#   [  9.133584  ]
#   [  8.136469  ]
#   [  8.422789  ]
#   [  9.061539  ]
#   [ 17.017216  ]
#   [ 46.551422  ]
#   [-11.819576  ]
#   [-11.379592  ]
#   [-13.66058   ]
#   [  9.871761  ]
#   [ 20.273603  ]
#   [ 13.964031  ]
#   [ 21.438047  ]
#   [ 17.951927  ]
#   [ 20.050709  ]
#   [ 17.466482  ]
#   [ 20.335691  ]
#   [ 17.470642  ]
#   [ 20.180021  ]
#   [ 17.472486  ]
#   [ 20.444618  ]
#   [ 17.51669   ]
#   [ 20.26298   ]
#   [ 17.575993  ]
#   [ 20.32647   ]
#   [ 17.569935  ]
#   [ 20.435604  ]
#   [ 17.55739   ]
#   [ 20.45211   ]
#   [ 17.529434  ]
#   [ 20.038229  ]
#   [ 17.47303   ]
#   [ 20.2897    ]
#   [ 17.400705  ]
#   [ 20.209658  ]
#   [ 17.343718  ]
#   [ 20.110083  ]
#   [ 17.262644  ]
#   [ 20.055195  ]
#   [ 17.345512  ]
#   [ 20.140987  ]
#   [ 17.305151  ]
#   [ 20.078714  ]
#   [ 17.35579   ]
#   [ 20.16453   ]
#   [ 17.386635  ]
#   [ 20.230556  ]
#   [ 17.477242  ]
#   [ 20.492094  ]
#   [ 17.388903  ]
#   [ 20.228865  ]
#   [ 17.449474  ]
#   [ 20.503216  ]
#   [ 17.528284  ]
#   [ 20.815521  ]
#   [ 17.622475  ]
#   [ 20.521164  ]
#   [ 17.591236  ]
#   [ 20.621248  ]
#   [ 17.551754  ]
#   [ 20.269354  ]
#   [ 17.620855  ]
#   [ 20.421608  ]
#   [ 17.645144  ]
#   [ 21.24226   ]
#   [ 17.583939  ]
#   [ 20.298237  ]
#   [ 17.580812  ]
#   [ 20.273989  ]
#   [ 17.595701  ]
#   [ 20.164207  ]
#   [ 17.582777  ]
#   [ 20.266598  ]
#   [ 17.57182   ]
#   [ 20.25341   ]
#   [ 17.584557  ]
#   [ 20.512613  ]
#   [ 17.57485   ]
#   [ 20.054693  ]
#   [ 17.564487  ]
#   [ 20.374012  ]
#   [ 17.512566  ]
#   [ 20.451693  ]
#   [ 17.487598  ]
#   [ 20.761374  ]
#   [ 17.429132  ]
#   [ 20.131924  ]
#   [ 17.536089  ]
#   [ 20.355022  ]
#   [ 17.428055  ]
#   [ 20.678589  ]
#   [ 17.409302  ]
#   [ 20.293013  ]
#   [ 17.389368  ]
#   [ 20.082867  ]
#   [ 17.462814  ]
#   [ 20.204773  ]
#   [ 17.426186  ]
#   [ 20.135532  ]
#   [ 17.525446  ]
#   [ 20.327745  ]
#   [ 17.561167  ]
#   [ 20.837406  ]
#   [ 17.581589  ]
#   [ 21.470846  ]
#   [ 17.535858  ]
#   [ 20.952173  ]
#   [ 17.512428  ]]]
#
# Actual Values:
# [[[4.36]]
#
#  [[4.25]]
#
#  [[7.35]]
#
#  [[7.76]]
#
#  [[5.87]]]

# %% [markdown]
# ## (2.2) A Baseline Model to compare our LSTM with!

# %% [markdown]
# 👉 In Time Series, an "intuitive" baseline model is to predict the **last seen value** for the future value(s) you want to forecast, as illustrated down below!
#
# <img src = "https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/rnn_time_series_no_horizon.png" width = 600, height = 300>

# %% [markdown]
# ❓ **Question (Last Seen Value Baseline Model)** ❓
#
# Create a new method `init_baseline` that initializes and compiles a baseline model in a similar way to the LSTM.
#
# - The baseline should be as a [📚 Keras Lambda Layer](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Lambda)
# - It should not even need a `fit` because it should have 0 trainable params
# - Then, compute the MAE for this FOLD and compare it with the MAE you obtained on the test set after training the LSTM
#
# <details>
#     <summary markdown='span'>💡 <i>Hint</i></summary>
#
# - Remember that `X_train[:,:,1]` is your temperature time-series (it's the second column in your `fold`)
# </details>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Lambda

def init_baseline():
    model = Sequential()
    
    # Lambda layer to extract the last value of the input sequence
    last_value = Lambda(lambda x: x[:, -1, :])  # Assuming your input shape is (batch_size, time_steps, features)
    
    # Add the Lambda layer to the model
    model.add(last_value)
    
    # Compile the model
    model.compile(optimizer='adam', loss='mae')  # Using MAE (Mean Absolute Error) as the loss function
    
    return model

# %%
# baseline_model = init_baseline()
# baseline_score = baseline_model.evaluate(X_test, y_test)
# print(f"- The Baseline MAE on the test set is equal to {round(baseline_score[1],2)} Celsius degrees")

# %%
baseline_model = init_baseline()
baseline_score = baseline_model.evaluate(X_test, y_test)
print(f"- The Baseline MAE on the test set is equal to {round(baseline_score, 2)} Celsius degrees")
# Out:
# 90/90 [==============================] - 0s 788us/step - loss: 139.3262
# - The Baseline MAE on the test set is equal to 139.33 Celsius degrees

# %%
# print(f"- The LSTM MAE on the test set is equal to {round(res[1],2)} Celsius degrees")
# print(f"🔥 Improvement of the LSTM model over the baseline (on this fold for the test set) = : {round((1 - (res[1]/baseline_score[1]))*100,2)} % 🔥")

# %%
# Evaluate the model on the test set
evaluation = model.evaluate(X_test, y_test)

print(f"\nTest Loss: {evaluation[0]}")
print(f"Test MAE: {evaluation[1]}")
# Out:
# 90/90 [==============================] - 2s 20ms/step - loss: 79.1541 - mean_absolute_error: 79.1541
#
# Test Loss: 79.15412139892578
# Test MAE: 79.15412139892578

# %%
print(f"- The LSTM MAE on the test set is equal to {round(evaluation[1],2)} Celsius degrees")
print(f"🔥 Improvement of the LSTM model over the baseline (on this fold for the test set) = : {round((1 - (evaluation[1]/baseline_score))*100,2)} % 🔥")
# Out:
# - The LSTM MAE on the test set is equal to 79.15 Celsius degrees
# 🔥 Improvement of the LSTM model over the baseline (on this fold for the test set) = : 43.19 % 🔥

# %% [markdown]
# ## (2.3) Cross-Validation

# %% [markdown]
# Remember **"The big picture"** ?
#
# <br>
#
# <details>
#     <summary markdown='span'><i>The big picture</i></summary>
#
#
# <b><u>Step 1: Cross-Validation in Time Series [FOLDS] </u></b>
#
# * Starting from this single Time Series, we will create <font color="#c91ac9">**FOLDS**</font>...
# * ... and train/evaluate our LSTM on these different <font color="#c91ac9">**FOLDS**</font> to conclude about the robustness of the neural network
# * It is very common to create ***hundreds*** of <font color="#c91ac9">**FOLDS**</font> in Time Series forecasting, so as to cover all type of external conditions: e.g.
#     - crash market periods 📉
#     - bull markets 📈
#     - atone markets 😴, etc...
#
# <b><u>Step 2: Holdout method within each fold [TRAIN-TEST SPLIT]</u></b>
#
# * For each <font color="#c91ac9">**FOLD**</font>, we will do a TRAIN-TEST SPLIT to:
#     * <font color=blue>**fit**</font> the model on the <font color=blue>**train**</font> set
#     * and <font color="#ff8005">**evaluate**</font> it on the <font color="#ff8005">**test**</font> set
#     * Always split the train set **chronologically** before the test set!
#
# 👇 The first two steps can be summarized in the following image that contains 4 FOLDS:
#
# <img src="https://bit.ly/3yLoa92" alt="Time Series Cross Validation" width="500" height="500">
#
#
# <b><u>Step 3: Sampling SEQUENCES in both the train set and the test set</u></b>
#
# In each <font color=blue>**train**</font> set and each <font color="#ff8005">**test**</font> set, we will create <font color=magenta>**random sequences**</font> as illustrated down below 👇:
#
# <img src="https://bit.ly/3Ri8Vfd" alt="Sequences in each fold" width="500" height="500">
#
#
# </details>
#
# ❗️ ***Warnings*** ❗️
#
# * Keep in mind that we did <u><i>step 2</i></u> (<font color="blue">train</font>/<font color="orange">test</font> split) and <u><i>step 3</i></u> (get_X_y) only **<font color="#c91ac9">for one single FOLD</font>**.
# * ***If we want to ensure the robustness of a model, we need to <font color="">cross-validate the model on <font color="#c91ac9">ALL the folds</font>!***

# %%
# Reminders of the global variables in this notebook

print(f'N_FEATURES = {N_FEATURES}') 
print(f'N_TARGETS = {N_TARGETS}') 
print('')
print(f'FOLD_LENGTH = {FOLD_LENGTH}')
print(f'FOLD_STRIDE = {FOLD_STRIDE}')
print(f'TRAIN_TEST_RATIO = {TRAIN_TEST_RATIO}')
print('')
print(f'N_TRAIN = {N_TRAIN}')
print(f'N_TEST = {N_TEST}')
print(f'INPUT_LENGTH = {INPUT_LENGTH}')
print(f'OUTPUT_LENGTH = {OUTPUT_LENGTH}')
# Out:
# N_FEATURES = 19
# N_TARGETS = 1
#
# FOLD_LENGTH = 8760
# FOLD_STRIDE = 728
# TRAIN_TEST_RATIO = 0.66
#
# N_TRAIN = 6666
# N_TEST = 3333
# INPUT_LENGTH = 112
# OUTPUT_LENGTH = 1

# %%
# Remember how many folds do we have ?
folds = get_folds(df, FOLD_LENGTH, FOLD_STRIDE)

print(f"WARNING, we have {len(folds)} FOLDS, so you may want to run the cross-validation of the RNN on Colab.")
# Out:
# WARNING, we have 21 FOLDS, so you may want to run the cross-validation of the RNN on Colab.

# %% [markdown]
# **❓ Cross validate your baseline and your model in a for-loop!❓**
#
# Re-using your previously defined methods
# - `get_folds`
# - `train_test_split`
# - `get_X_y`
# - `init_model`
# - `init_baseline`

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

def init_model(X_train, y_train):
    model = Sequential()
    model.add(LSTM(100, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mae', metrics=['mae'])
    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping

def cross_validate_baseline_and_lstm():
    '''
    This function cross-validates 
    - the "last seen value" baseline model
    - the RNN model
    '''
    
    list_of_mae_baseline_model = []
    list_of_mae_recurrent_model = []
    
    # 0 - Creating folds
    # =========================================    
    folds = get_folds(df, FOLD_LENGTH, FOLD_STRIDE)
    
    for fold_id, fold in enumerate(folds):
        
        # 1 - Train/Test split the current fold
        # =========================================
        (fold_train, fold_test) = train_test_split(fold, TRAIN_TEST_RATIO, INPUT_LENGTH)                   

        X_train, y_train = get_X_y(fold_train, N_TRAIN, INPUT_LENGTH, OUTPUT_LENGTH,TARGET)
        X_test, y_test = get_X_y(fold_test, N_TEST, INPUT_LENGTH, OUTPUT_LENGTH,TARGET)
        
        # 2 - Modelling
        # =========================================
        ##### Baseline Model
        baseline_model = init_baseline()
        mae_baseline = baseline_model.evaluate(X_test, y_test, verbose=0)  # Remove [1]
        list_of_mae_baseline_model.append(mae_baseline)
        print("-" * 50)
        print(f"MAE baseline fold n°{fold_id} = {round(mae_baseline, 2)}")
        ##### Baseline Model
#         baseline_model = init_baseline()
#         mae_baseline = baseline_model.evaluate(X_test, y_test, verbose=0)[1]
#         list_of_mae_baseline_model.append(mae_baseline)
#         print("-"*50)
#         print(f"MAE baseline fold n°{fold_id} = {round(mae_baseline, 2)}")

        ##### LSTM Model
        model = init_model(X_train, y_train)
        es = EarlyStopping(monitor = "val_mae",
                           mode = "min",
                           patience = 2, 
                           restore_best_weights = True)
        history = model.fit(X_train, y_train,
                            validation_split = 0.3,
                            shuffle = False,
                            batch_size = 32,
                            epochs = 50,
                            callbacks = [es],
                            verbose = 0)
        res = model.evaluate(X_test, y_test, verbose=0)
        mae_lstm = res[1]
        list_of_mae_recurrent_model.append(mae_lstm)
        print(f"MAE LSTM fold n°{fold_id} = {round(mae_lstm, 2)}")
        
        ##### Comparison LSTM vs Baseline for the current fold
        print(f"🏋🏽‍♂️ improvement over baseline: {round((1 - (mae_lstm/mae_baseline))*100,2)} % \n")

    return list_of_mae_baseline_model, list_of_mae_recurrent_model

# %%
# %%time
# WARNING : it takes 75 minutes to run this cell 
mae_baselines, mae_lstms = cross_validate_baseline_and_lstm()

# %%
print(f"average percentage improvement over baseline = {round(np.mean(1 - (np.array(mae_lstms)/np.array(mae_baselines))),2)*100}%")

# %% [markdown]
# ## Acknowledgments

# %% [markdown]
# * This challenge was truly inspired by the `Time Series Forecasting` tutorial from `Google>Tensorflow>Keras`
# * The technical functions were inspired by Bruno Lajoie's [data-template package about Time Series](https://github.com/lewagon/data-templates/tree/main/project-boilerplates)
